# %% [markdown]
# # Classification: Cats VS Dogs
#
# We downloaded the dataset from kaggle. The training archive contains 25,000 images of dogs and cats.

# %% [markdown]
# # Using own data with included Datasets

# %%
import os
import mxnet as mx
import matplotlib.pyplot as plt
from mxnet import gluon
from mxnet import nd, autograd
import numpy as np
from mxnet.gluon.model_zoo import vision

# %%
def aug_transform(data, label):
    data = data.astype('float32')/255 # normalize the data
    size= 224
    aug = mx.image.ForceResizeAug((size,size)) # resize the image to 224x224
    data = aug(data)
    data=data.transpose((2, 0, 1))
    return data, label

# %% [markdown]
# # Reading Training date

# %%
data_folder = "data"
dataset_name = "CatsVsDogs"

training_path = os.path.join(data_folder, dataset_name)
print(training_path)

train_dataset = mx.gluon.data.vision.datasets.ImageFolderDataset(training_path,transform=aug_transform)
# Out:
# data/CatsVsDogs

# %%
sample_idx = 17990
sample = train_dataset[sample_idx]
data = sample[0]
label = sample[1]

#plt.imshow(data.asnumpy(), cmap='gray')
print("Data type: {}".format(data.shape))
print("Label: {}".format(label))
print("Label description: {}".format(train_dataset.synsets[label]))
assert label == 1
# Out:
# Data type: (3, 224, 224)
# Label: 1
# Label description: dog

# %% [markdown]
# # Test data

# %%
testing_path = os.path.join(data_folder, "{}_test".format(dataset_name))
print(testing_path)
test_dataset = mx.gluon.data.vision.datasets.ImageFolderDataset(testing_path,transform=aug_transform)
# Out:
# data/CatsVsDogs_test

# %%
sample_idx = 199

sample = test_dataset[sample_idx]
data = sample[0]
label = sample[1]

#plt.imshow(data.asnumpy(), cmap='gray')
print("Data type: {}".format(data.shape))
print("Label: {}".format(label))
print("Label description: {}".format(train_dataset.synsets[label]))
# Out:
# Data type: (3, 224, 224)
# Label: 0
# Label description: cat

# %% [markdown]
# # Batch size and DataLoader for train_data, test_dataset

# %%
batch_size = 32
train_data = gluon.data.DataLoader(train_dataset, batch_size, shuffle=True)
test_data = gluon.data.DataLoader(test_dataset,batch_size, shuffle=False)

# %% [markdown]
# # Initialize parameters

# %%
ctx = mx.gpu()
network=vision.resnet152_v2(pretrained=True, ctx=ctx)

# %% [markdown]
# # Fine-tuning pre-trained models

# %%
NUM_CLASSES = 2
with network.name_scope():
    network.output = gluon.nn.Dense(2)

# %%
network.collect_params().initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)
# Out:
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm0_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm0_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm0_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm0_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_conv0_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm1_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm1_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm1_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm1_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm0_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm0_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm0_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm0_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv0_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm1_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm1_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm1_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm1_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv1_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm2_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm2_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm2_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm2_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv2_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv3_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm3_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm3_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm3_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm3_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv4_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm4_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm4_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm4_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm4_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv5_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm5_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm5_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm5_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm5_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv6_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm6_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm6_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm6_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm6_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv7_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm7_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm7_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm7_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm7_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv8_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm8_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm8_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm8_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_batchnorm8_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage1_conv9_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm0_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm0_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm0_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm0_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv0_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm1_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm1_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm1_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm1_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv1_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm2_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm2_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm2_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm2_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv2_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv3_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm3_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm3_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm3_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm3_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv4_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm4_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm4_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm4_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm4_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv5_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm5_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm5_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm5_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm5_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv6_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm6_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm6_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm6_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm6_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv7_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm7_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm7_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm7_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm7_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv8_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm8_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm8_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm8_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm8_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv9_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm9_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm9_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm9_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm9_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv10_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm10_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm10_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm10_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm10_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv11_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm11_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm11_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm11_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm11_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv12_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm12_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm12_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm12_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm12_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv13_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm13_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm13_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm13_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm13_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv14_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm14_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm14_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm14_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm14_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv15_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm15_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm15_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm15_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm15_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv16_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm16_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm16_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm16_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm16_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv17_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm17_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm17_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm17_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm17_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv18_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm18_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm18_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm18_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm18_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv19_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm19_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm19_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm19_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm19_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv20_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm20_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm20_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm20_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm20_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv21_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm21_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm21_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm21_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm21_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv22_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm22_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm22_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm22_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_batchnorm22_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage2_conv23_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# ...
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage3_batchnorm106_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage3_conv107_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage3_batchnorm107_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage3_batchnorm107_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage3_batchnorm107_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage3_batchnorm107_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage3_conv108_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm0_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm0_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm0_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm0_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv0_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm1_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm1_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm1_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm1_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv1_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm2_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm2_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm2_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm2_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv2_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv3_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm3_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm3_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm3_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm3_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv4_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm4_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm4_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm4_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm4_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv5_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm5_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm5_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm5_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm5_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv6_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm6_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm6_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm6_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm6_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv7_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm7_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm7_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm7_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm7_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv8_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm8_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm8_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm8_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_batchnorm8_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_stage4_conv9_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm2_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm2_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm2_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /home/ubuntu/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/gluon/parameter.py:320: UserWarning: Parameter resnetv20_batchnorm2_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)

# %% [markdown]
# # Optimizer

# %%
trainer = gluon.Trainer(network.collect_params(), 'adam', {'learning_rate': .0001})

# %% [markdown]
# # Softmax cross-entropy loss

# %%
softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()

# %% [markdown]
# # Evaluation Loop

# %%
def evaluate_accuracy(data_iterator, net):
    acc = mx.metric.Accuracy()
    curr_loss= []
    for d, l in data_iterator:
        data = d.as_in_context(ctx)
        label = l.as_in_context(ctx)
        output = net(data)
        
        loss = softmax_cross_entropy(output, label)
        
        predictions = nd.argmax(output, axis=1)
        acc.update(preds=[predictions], labels=[label])
        
        curr_loss.append(nd.mean(loss).asscalar())
        
        #print(acc)
    
    return acc.get()[1], np.average(curr_loss)

# %% [markdown]
# # Training loop

# %%
epochs = 10
smoothing_constant = .1
metric = mx.metric.Accuracy()

train_acc=[]
val_acc=[]

train_loss=[]
val_loss=[]


for e in range(epochs):
    metric.reset()
    for i, (d, l) in enumerate(train_data):
        data = d.as_in_context(ctx)
        label = l.as_in_context(ctx)
        with autograd.record():
            output = network(data)
            loss = softmax_cross_entropy(output, label)
        
        loss.backward()
        trainer.step(data.shape[0])
                
        ##########################
        #  Keep a moving average of the losses
        ##########################
        metric.update([label], [output])
        curr_loss = nd.mean(loss).asscalar()
        moving_loss = (curr_loss if ((i == 0) and (e == 0))
                       else (1 - smoothing_constant) * moving_loss + (smoothing_constant) * curr_loss)

        
        if i % 10 == 0 and i > 0:
                name, acc = metric.get()
                print('[Epoch %d Batch %d] Loss: %s Training %s=%f'%(e, i, moving_loss, name, acc))
           
    _, train_accuracy = metric.get()
    
    test_accuracy,test_loss = evaluate_accuracy(test_data, network)
    
    train_acc.append(train_accuracy)
    val_acc.append(test_accuracy)
    
    train_loss.append(moving_loss)
    val_loss.append(test_loss)
    
    #_, train_accuracy = metric.get()
    #print("Epoch %s. Loss: %s, Train_acc %s\n" % (e, moving_loss, train_accuracy))

    #test_accuracy = evaluate_accuracy(test_data, network)
    print("\nEpoch %s., Validation Accuracy %s,Validation Loss =%s \n" % (e, test_accuracy,val_loss[e]))
# Out:
# [Epoch 0 Batch 10] Loss: 0.3265344582383592 Training accuracy=0.928977
# [Epoch 0 Batch 20] Loss: 0.1856434173116093 Training accuracy=0.941964
# [Epoch 0 Batch 30] Loss: 0.12746406813525482 Training accuracy=0.947581
# [Epoch 0 Batch 40] Loss: 0.12173914515400275 Training accuracy=0.950457
# [Epoch 0 Batch 50] Loss: 0.11474262104692635 Training accuracy=0.954044
# [Epoch 0 Batch 60] Loss: 0.11033477441916378 Training accuracy=0.955943
# [Epoch 0 Batch 70] Loss: 0.07721241519461354 Training accuracy=0.959067
# [Epoch 0 Batch 80] Loss: 0.0729287988174067 Training accuracy=0.961420
# [Epoch 0 Batch 90] Loss: 0.07985138522478842 Training accuracy=0.961538
# [Epoch 0 Batch 100] Loss: 0.07352247254280043 Training accuracy=0.962252
# [Epoch 0 Batch 110] Loss: 0.06396595485255266 Training accuracy=0.963401
# [Epoch 0 Batch 120] Loss: 0.059699738657245385 Training accuracy=0.964360
# [Epoch 0 Batch 130] Loss: 0.054968010401567124 Training accuracy=0.965172
# [Epoch 0 Batch 140] Loss: 0.06513032572966244 Training accuracy=0.966090
# [Epoch 0 Batch 150] Loss: 0.07109753264331195 Training accuracy=0.966680
# [Epoch 0 Batch 160] Loss: 0.09841818494427373 Training accuracy=0.966227
# [Epoch 0 Batch 170] Loss: 0.08419342506866649 Training accuracy=0.966374
# [Epoch 0 Batch 180] Loss: 0.05401877459569204 Training accuracy=0.967541
# [Epoch 0 Batch 190] Loss: 0.04966643043893081 Training accuracy=0.968259
# [Epoch 0 Batch 200] Loss: 0.0617772358610849 Training accuracy=0.968750
# [Epoch 0 Batch 210] Loss: 0.045818050745694366 Training accuracy=0.969194
# [Epoch 0 Batch 220] Loss: 0.04217743072455785 Training accuracy=0.969740
# [Epoch 0 Batch 230] Loss: 0.06533458962788988 Training accuracy=0.970103
# [Epoch 0 Batch 240] Loss: 0.0675738624860593 Training accuracy=0.970436
# [Epoch 0 Batch 250] Loss: 0.05906918183335909 Training accuracy=0.970618
# [Epoch 0 Batch 260] Loss: 0.07785034321906346 Training accuracy=0.970666
# [Epoch 0 Batch 270] Loss: 0.08926389630045725 Training accuracy=0.970595
# [Epoch 0 Batch 280] Loss: 0.062337774758222296 Training accuracy=0.970974
# [Epoch 0 Batch 290] Loss: 0.05594702607800499 Training accuracy=0.971435
# [Epoch 0 Batch 680] Loss: 0.04540485316370294 Training accuracy=0.975266
# [Epoch 0 Batch 690] Loss: 0.032155436576215564 Training accuracy=0.975534
# [Epoch 0 Batch 700] Loss: 0.07521809600734004 Training accuracy=0.975348
# [Epoch 0 Batch 710] Loss: 0.07332573403061574 Training accuracy=0.975343
# [Epoch 0 Batch 720] Loss: 0.08016106133864004 Training accuracy=0.975251
# [Epoch 0 Batch 730] Loss: 0.04818401836824496 Training accuracy=0.975462
# [Epoch 0 Batch 740] Loss: 0.0526900851099079 Training accuracy=0.975540
#
# Epoch 0., Validation Accuracy 0.988,Validation Loss =0.03275175
#
# [Epoch 1 Batch 10] Loss: 0.04349987825900898 Training accuracy=0.985795
# [Epoch 1 Batch 20] Loss: 0.03622993013931975 Training accuracy=0.991071
# [Epoch 1 Batch 30] Loss: 0.028386485124247823 Training accuracy=0.989919
# [Epoch 1 Batch 40] Loss: 0.019537921744640977 Training accuracy=0.991616
# [Epoch 1 Batch 50] Loss: 0.02771025318649872 Training accuracy=0.991422
# [Epoch 1 Batch 60] Loss: 0.04780165384612449 Training accuracy=0.990779
# [Epoch 1 Batch 70] Loss: 0.024788743025809898 Training accuracy=0.992077
# [Epoch 1 Batch 80] Loss: 0.017288552039868992 Training accuracy=0.992284
# [Epoch 1 Batch 90] Loss: 0.023467828210807277 Training accuracy=0.992102
# [Epoch 1 Batch 100] Loss: 0.03604520226144867 Training accuracy=0.991027
# [Epoch 1 Batch 110] Loss: 0.055170393177320906 Training accuracy=0.990428
# [Epoch 1 Batch 120] Loss: 0.03741030791896402 Training accuracy=0.989928
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-5e246284db0a> in <module>()
#      13     metric.reset()
#      14     for i, (d, l) in enumerate(train_data):
# ---> 15         data = d.as_in_context(ctx)
#      16         label = l.as_in_context(ctx)
#      17         with autograd.record():
#
# ~/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in as_in_context(self, context)
#    1926         False
#    1927         """
# -> 1928         if self.context == context:
#    1929             return self
#    1930         return self.copyto(context)
#
# ~/anaconda3/envs/mxnet/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in context(self)
#    1693         check_call(_LIB.MXNDArrayGetContext(
#    1694             self.handle, ctypes.byref(dev_typeid), ctypes.byref(dev_id)))
# -> 1695         return Context(Context.devtype2str[dev_typeid.value], dev_id.value)
#    1696
#    1697     @property
#
# KeyboardInterrupt:

# %% [markdown]
# # Learning curve ( Plot Loss and Accuracy)

# %%
plt.ion()
fig = plt.figure()
subfig=fig.add_subplot(122)
subfig.plot(train_acc, label = 'training')
if val_acc is not None:
    subfig.plot(val_acc, label = 'validation')
    
subfig.set_title('Model Accuracy')
subfig.set_xlabel('Epoch')
subfig.legend(loc='upper left')

subfig1=fig.add_subplot(121)
subfig1.plot(train_loss, label='training')
if val_loss is not None:
    subfig1.plot(val_loss, label = 'validation')
subfig1.set_title('Model Loss')
subfig1.set_xlabel('Epoch')
subfig1.legend(loc='upper left')
plt.ioff()

# %% [markdown]
# The plot shows after epoch 6 the training accuracy is high and the validation score is low, which shows it is overfitting the training data. The best accuracy we can get using Alnext is 90.8%.
